# %%
import os
from skimage.io import imread
from skimage.transform import resize
from PIL import Image
import numpy as np

# %%
Image.open('cats/cat.137.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=390x500>

# %%
img = imread('cats/cat.137.jpg')
print(img)
# Out:
# [[[140 127 110]
#   [140 127 110]
#   [139 126 109]
#   ...
#   [148 131 103]
#   [152 135 107]
#   [154 137 109]]
#
#  [[137 124 107]
#   [136 123 106]
#   [135 122 105]
#   ...
#   [143 126  98]
#   [147 130 102]
#   [153 136 108]]
#
#  [[136 123 104]
#   [135 122 103]
#   [134 121 102]
#   ...
#   [141 126  97]
#   [144 129 100]
#   [150 135 106]]
#
#  ...
#
#  [[163 155 132]
#   [160 153 127]
#   [158 148 123]
#   ...
#   [151 137 110]
#   [163 149 122]
#   [153 139 112]]
#
#  [[163 155 132]
#   [160 153 127]
#   [158 148 123]
#   ...
#   [152 138 111]
#   [165 151 124]
#   [155 141 114]]
#
#  [[163 155 132]
#   [160 153 127]
#   [158 148 123]
#   ...
#   [154 140 113]
#   [167 153 126]
#   [156 142 115]]]

# %%
img = resize(img,(15,15))
img
# Out:
# array([[[0.54329803, 0.50178519, 0.41439754],
#         [0.54609244, 0.50210621, 0.41151697],
#         [0.5527245 , 0.50716538, 0.42036542],
#         [0.55679142, 0.51238831, 0.42883701],
#         [0.55253918, 0.511382  , 0.42611969],
#         [0.55631019, 0.51237208, 0.42404012],
#         [0.5648456 , 0.51873269, 0.42859763],
#         [0.57022519, 0.52327618, 0.43175316],
#         [0.57135962, 0.52659454, 0.43045829],
#         [0.57163422, 0.52572631, 0.42431133],
#         [0.5622366 , 0.51356336, 0.41538729],
#         [0.48888587, 0.44412939, 0.36247263],
#         [0.36420705, 0.32555864, 0.26699287],
#         [0.48828894, 0.43583192, 0.35483477],
#         [0.55678711, 0.5044804 , 0.40613367]],
#
#        [[0.5552833 , 0.51459102, 0.42461612],
#         [0.56009393, 0.51723121, 0.42586291],
#         [0.5605125 , 0.51579504, 0.42114869],
#         [0.56607986, 0.51927191, 0.4263705 ],
#         [0.55873447, 0.51338439, 0.42155018],
# ...

# %%
img = img.flatten()
img
# Out:
# array([0.54329803, 0.50178519, 0.41439754, 0.54609244, 0.50210621,
#        0.41151697, 0.5527245 , 0.50716538, 0.42036542, 0.55679142,
#        0.51238831, 0.42883701, 0.55253918, 0.511382  , 0.42611969,
#        0.55631019, 0.51237208, 0.42404012, 0.5648456 , 0.51873269,
#        0.42859763, 0.57022519, 0.52327618, 0.43175316, 0.57135962,
#        0.52659454, 0.43045829, 0.57163422, 0.52572631, 0.42431133,
#        0.5622366 , 0.51356336, 0.41538729, 0.48888587, 0.44412939,
#        0.36247263, 0.36420705, 0.32555864, 0.26699287, 0.48828894,
#        0.43583192, 0.35483477, 0.55678711, 0.5044804 , 0.40613367,
#        0.5552833 , 0.51459102, 0.42461612, 0.56009393, 0.51723121,
#        0.42586291, 0.5605125 , 0.51579504, 0.42114869, 0.56607986,
#        0.51927191, 0.4263705 , 0.55873447, 0.51338439, 0.42155018,
#        0.56506606, 0.5171531 , 0.42210823, 0.57145869, 0.52548379,
#        0.42910356, 0.57321702, 0.52761931, 0.42930643, 0.57319862,
# ...

# %%
categories = ['cats','dogs']
input_dir = "C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6"
for category in categories:
    for file in os.listdir(os.path.join(input_dir,category)):
        img_path = os.path.join(input_dir,category,file)
        print(img_path)
# Out:
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.0.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.1.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.10.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.100.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.101.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.102.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.103.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.104.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.105.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.106.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.107.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.108.jpg
# C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.109.jpg
# ...

# %%
Image.open('C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\cats\cat.104.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=253x399>

# %%
Image.open('C:/Users/Acer/Desktop/Intellipaat/Case Study/Case Study 6\dogs\dog.240.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=344x335>

# %% [markdown]
# # Image conversion to array

# %%
data = []
labels = []

# %%
for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir,category)):
        img_path = os.path.join(input_dir,category,file)
        img = imread(img_path) # img is a numpy array
        img = resize(img,(15,15))
        data.append(img.flatten())
        labels.append(category_idx)

# %%
labels = np.array(labels)
data = np.asarray(data)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       243
#            1       0.60      0.56      0.58       200
#
#     accuracy                           0.63       443
#    macro avg       0.63      0.63      0.63       443
# weighted avg       0.63      0.63      0.63       443

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[168  75]
#  [ 87 113]]

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [[155  88]
#  [ 97 103]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       243
#            1       0.54      0.52      0.53       200
#
#     accuracy                           0.58       443
#    macro avg       0.58      0.58      0.58       443
# weighted avg       0.58      0.58      0.58       443

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=1000)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [[182  61]
#  [ 96 104]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70       243
#            1       0.63      0.52      0.57       200
#
#     accuracy                           0.65       443
#    macro avg       0.64      0.63      0.63       443
# weighted avg       0.64      0.65      0.64       443
